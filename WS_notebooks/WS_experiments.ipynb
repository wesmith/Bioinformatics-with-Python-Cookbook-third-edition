# %% [markdown]
# # WS_experiments.ipynb
# # WESmith 12/02/22
# ## WS created this notebook to experiment with various algorithms related to bioinformatics

# %%
import os
from collections import defaultdict
import gffutils
from Bio import Seq, SeqIO
import matplotlib.pyplot as plt
import ws_gene_utils as ws

# %% [markdown]
# ## GET DATA

# %%
# move big files to Downloads so it will not be backed up
data_dir   = '/home/smithw/Downloads/ch05_data'
name_gff   = 'VectorBase-55_AgambiaePEST.gff'
name_fasta = 'VectorBase-57_AgambiaePEST_Genome.fasta'
# ag.db was created in WS_ch05C.ipynb
db_name    = os.path.join(data_dir, 'ag.db')
fasta_name = os.path.join(data_dir, name_fasta)

# %%
db = gffutils.FeatureDB(db_name)

# %% [markdown]
# ## PLOT GENE SEQUENCES FROM GFF FILES

# %%
# some test genes
genes = ['AGAP010404', 'AGAP001111', 'AGAP003566', 'AGAP004707', 'AGAP010865']

# %%
dd = [ws.PlotGFF(db, gene_id, xwin=20) for gene_id in genes]

# %%
for k in dd: k.plot()
